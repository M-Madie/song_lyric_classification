# %% [markdown]
# ### Task - Create model that predicats if a sentence from a song belongs to 50 Cent or Britney spears

# %% [markdown]
# ###### This file includes scraping and cleaning of list of songs for 50 Cent, Data will be shared with a collegue, who will share Songs of Britney Spears.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import time

# %% [markdown]
# ### Step 1 - Obtain Song Lyrics from Urls

# %%
# open Artist Url

s_url = 'https://www.lyrics.com/artist/50-Cent/372609'
s_headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
s_response = requests.get(s_url, headers=s_headers)
#s_response.text

# %%
# turn into Soup object

soup = BeautifulSoup(s_response.text, 'html.parser')
#type(soup)

# %%
# Extract song titles, and song links from Artist Url

song_links = soup.find_all('td', attrs={'class': 'tal qx'})
song_titles = []
lyric_links =[]

for row in song_links:
    song_titles.append(row.a.text)
    lyric_links.append(row.a['href'])

# %%
# Turn into a DataFrame

fifty_cent = pd.DataFrame({'song_title':song_titles,'link': ['https://www.lyrics.com'+ str(i) for i in lyric_links]})
fifty_cent
# Out:
#                       song_title  \
# 0              Remember the Name
# 1                      Yeah Yeah
# 2                     In Da Club
# 3                     I Get High
# 4                     If I Can't
# ...                          ...
# 1681  In Da Club (Shake Sh*t Up)
# 1682                  In da Club
# 1683                   Stunt 101
# 1684              We Up [Edited]
# 1685                    P.I.M.P.
#
#                                                    link
# 0     https://www.lyrics.com/lyric/36259009/50+Cent/...
# 1     https://www.lyrics.com/lyric/35373551/50+Cent/...
# 2     https://www.lyrics.com/lyric/35567415/50+Cent/...
# 3     https://www.lyrics.com/lyric/35164479/50+Cent/...
# 4     https://www.lyrics.com/lyric/35098290/50+Cent/...
# ...                                                 ...
# 1681  https://www.lyrics.com/lyric/17222602/50+Cent/...
# 1682  https://www.lyrics.com/lyric/19185906/50+Cent/...
# 1683  https://www.lyrics.com/lyric/19185805/50+Cent/...
# 1684  https://www.lyrics.com/lyric/29260338/50+Cent/...
# 1685  https://www.lyrics.com/lyric/27835926/50+Cent/...
#
# [1686 rows x 2 columns]

# %%
# Check for duplicates
fifty_cent[fifty_cent['song_title']=='In Da Club']
# Out:
#       song_title                                               link
# 2     In Da Club  https://www.lyrics.com/lyric/35567415/50+Cent/...
# 7     In Da Club  https://www.lyrics.com/lyric/35168662/50+Cent/...
# 9     In Da Club  https://www.lyrics.com/lyric/34804707/50+Cent/...
# 30    In Da Club  https://www.lyrics.com/lyric/34595206/50+Cent/...
# 35    In Da Club  https://www.lyrics.com/lyric/34218461/50+Cent/...
# 37    In Da Club  https://www.lyrics.com/lyric/34549272/50+Cent/...
# 41    In Da Club  https://www.lyrics.com/lyric/31967113/50+Cent/...
# 136   In Da Club  https://www.lyrics.com/lyric/35286484/50+Cent/...
# 141   In Da Club  https://www.lyrics.com/lyric/31566976/50+Cent/...
# 145   In Da Club  https://www.lyrics.com/lyric/33182333/50+Cent/...
# 148   In Da Club  https://www.lyrics.com/lyric/33019604/50+Cent/...
# 186   In Da Club  https://www.lyrics.com/lyric/27398921/50+Cent/...
# 272   In Da Club  https://www.lyrics.com/lyric/18252955/50+Cent/...
# 370   In Da Club  https://www.lyrics.com/lyric/15137231/50+Cent/...
# 538   In Da Club  https://www.lyrics.com/lyric/10497238/50+Cent/...
# 556   In Da Club  https://www.lyrics.com/lyric/14756188/50+Cent/...
# 558   In Da Club  https://www.lyrics.com/lyric/14656887/50+Cent/...
# 665   In Da Club  https://www.lyrics.com/lyric/14560342/50+Cent/...
# 679   In Da Club  https://www.lyrics.com/lyric/28993685/50+Cent/...
# 937   In Da Club  https://www.lyrics.com/lyric/9548826/50+Cent/I...
# 938   In Da Club  https://www.lyrics.com/lyric/10391271/50+Cent/...
# 940   In Da Club  https://www.lyrics.com/lyric/27570675/50+Cent/...
# 941   In Da Club  https://www.lyrics.com/lyric/15510034/50+Cent/...
# 948   In Da Club  https://www.lyrics.com/lyric/36073461/50+Cent/...
# 996   In Da Club  https://www.lyrics.com/lyric/35805024/50+Cent/...
# 1011  In Da Club  https://www.lyrics.com/lyric/35801888/50+Cent/...
# 1085  In Da Club  https://www.lyrics.com/lyric/15197913/50+Cent/...
# 1110  In Da Club  https://www.lyrics.com/lyric/27570692/50+Cent/...
# 1151  In Da Club  https://www.lyrics.com/lyric/25857413/50+Cent/...
# 1155  In Da Club  https://www.lyrics.com/lyric/17511421/50+Cent/...
# 1222  In Da Club  https://www.lyrics.com/lyric/19017164/50+Cent/...
# 1253  In Da Club  https://www.lyrics.com/lyric/19866618/50+Cent/...
# 1366  In Da Club  https://www.lyrics.com/lyric/14655617/50+Cent/...
# 1371  In Da Club  https://www.lyrics.com/lyric/6190738/50+Cent/I...
# 1373  In Da Club  https://www.lyrics.com/lyric/6845523/50+Cent/I...
# 1375  In Da Club  https://www.lyrics.com/lyric/6845514/50+Cent/I...
# 1400  In Da Club  https://www.lyrics.com/lyric/8806826/50+Cent/I...
# 1466  In Da Club  https://www.lyrics.com/lyric/26657354/50+Cent/...
# 1472  In Da Club  https://www.lyrics.com/lyric/21714294/50+Cent/...
# 1500  In Da Club  https://www.lyrics.com/lyric/34275615/50+Cent/...
# 1507  In Da Club  https://www.lyrics.com/lyric/37072848/50+Cent/...
# 1510  In Da Club  https://www.lyrics.com/lyric/37063834/50+Cent/...
# 1512  In Da Club  https://www.lyrics.com/lyric/37058727/50+Cent/...
# 1514  In Da Club  https://www.lyrics.com/lyric/37051960/50+Cent/...
# 1516  In Da Club  https://www.lyrics.com/lyric/37048492/50+Cent/...
# 1525  In Da Club  https://www.lyrics.com/lyric/37078262/50+Cent/...
# 1537  In Da Club  https://www.lyrics.com/lyric/37103929/50+Cent/...
# 1555  In Da Club  https://www.lyrics.com/lyric/27226819/50+Cent/...
# 1558  In Da Club  https://www.lyrics.com/lyric/36488814/50+Cent/...
# 1579  In Da Club  https://www.lyrics.com/lyric/36104769/50+Cent/...
# 1588  In Da Club  https://www.lyrics.com/lyric/33998378/50+Cent/...

# %%
# Remove duplicates
fifty_cent_dropped = fifty_cent.drop_duplicates(subset='song_title', keep='first', inplace=False)
fifty_cent_dropped = fifty_cent_dropped.reset_index()
fifty_cent_dropped = fifty_cent_dropped.drop('index', axis=1)
fifty_cent_dropped
# Out:
#                                       song_title  \
# 0                              Remember the Name
# 1                                      Yeah Yeah
# 2                                     In Da Club
# 3                                     I Get High
# 4                                     If I Can't
# ..                                           ...
# 526                                   Hit You Up
# 527  MJB Da MVP [Alternate Version; Bonus Track]
# 528              Could've Been You [Bonus Track]
# 529                        Nah I'm Talking 'Bout
# 530                               We Up [Edited]
#
#                                                   link
# 0    https://www.lyrics.com/lyric/36259009/50+Cent/...
# 1    https://www.lyrics.com/lyric/35373551/50+Cent/...
# 2    https://www.lyrics.com/lyric/35567415/50+Cent/...
# 3    https://www.lyrics.com/lyric/35164479/50+Cent/...
# 4    https://www.lyrics.com/lyric/35098290/50+Cent/...
# ..                                                 ...
# 526  https://www.lyrics.com/lyric/10345621/50+Cent/...
# 527  https://www.lyrics.com/lyric/13441239/50+Cent/...
# 528  https://www.lyrics.com/lyric/29458357/50+Cent/...
# 529  https://www.lyrics.com/lyric/31649270/50+Cent/...
# 530  https://www.lyrics.com/lyric/29260338/50+Cent/...
#
# [531 rows x 2 columns]

# %%
# Remove special characters from the song names (prevent error with song name)
import string
pattern = r'[' + string.punctuation + ']'
for i in range(len(fifty_cent_dropped['song_title'])):
    fifty_cent_dropped['song_title'][i] = re.sub(pattern, '', fifty_cent_dropped['song_title'][i])

# %%
# loop through the links of song_lyric_urls    
# Extract Lyric Text
# create Artist Folder, and save lyrics to text files

import os
for i in range(209,len(fifty_cent_dropped.link)):
    lyrics = BeautifulSoup(requests.get(fifty_cent_dropped.link[i]).text)
    time.sleep(3)
    try:
        filename = f"song/{fifty_cent_dropped.song_title[i]}.txt"
        os.makedirs(os.path.dirname(filename), exist_ok=True)
        with open(filename,'w') as f:
            f.write(lyrics.find('div',attrs={'class':'lyric clearfix'}).pre.text)            
            f.close()
    except:
        continue

# %% [markdown]
# ### Step 2 - Extract Lyrics from text files into a DataFrame, and clean Data

# %% [markdown]
# - original dataframe 531 urls
# - 502 text files created (errors ignored via try, except)
# - despite removal of duplicate song_titles in Step 1, there are repetition of songd with slightly different titles
# - duplicate of songs will not be included in final DataFrame
# - empty text files will not be included
# - final - 291 songs included

# %%
# open each file, extract text, split into rows, and strip
# append in a growing List of Song_texts
# try and except - to ignore error resulting from removed files
# extract song name into a new list for each successful extraction of text

song_text = []
song_name = []
for i in range(len(fifty_cent_dropped.link)):
    try:
        filename = f"song/{fifty_cent_dropped.song_title[i]}.txt"
        with open(filename, "r") as f:
            song_text.append(f.read())
            f.close()
        song_name.append(fifty_cent_dropped.song_title[i])
    except:
        continue

# %%
len(song_text), len(song_name)      # why 314 ??? check ... also check better way to exclude duplicated files
# Out:
# (314, 314)

# %%
# Turn list of song_text >>> DataFrame with row for each sentence of a song, column song name, column artist name

df_final = pd.DataFrame()
for i in range(len(song_text)):
    rows = song_text[i].split("\n")                                         # Split Song_text into list of sentences
    rows_stripped = [rows[n].strip() for n in range(len(rows))]             # loop through sentences and strip
    rows_stripped = pd.DataFrame(rows_stripped)                             # turn into DataFrame
    rows_stripped['song_name'] = song_name[i]                               # add column, and fill with song name
    rows_stripped['artist_name'] = '50 Cent'                                # add column, and fill with artist name
    df_final = pd.concat([df_final, rows_stripped], axis=0)                 # Append to Final DataFrame

# %%
df_final = df_final.rename({0: 'lyrics_row'}, axis=1)
df_final.head()
# Out:
#                                           lyrics_row          song_name  \
# 0  Yeah, I was born a misfit, grew up ten miles f...  Remember the Name
# 1                                                     Remember the Name
# 2    Wanted to make it big, I wished it to existence  Remember the Name
# 3                                                     Remember the Name
# 4     I never was a sick kid, always dismissed quick  Remember the Name
#
#   artist_name
# 0     50 Cent
# 1     50 Cent
# 2     50 Cent
# 3     50 Cent
# 4     50 Cent

# %%
df_final = df_final.reset_index()
df_final = df_final.drop('index', axis=1)
df_final.head()
# Out:
#                                           lyrics_row          song_name  \
# 0  Yeah, I was born a misfit, grew up ten miles f...  Remember the Name
# 1                                                     Remember the Name
# 2    Wanted to make it big, I wished it to existence  Remember the Name
# 3                                                     Remember the Name
# 4     I never was a sick kid, always dismissed quick  Remember the Name
#
#   artist_name
# 0     50 Cent
# 1     50 Cent
# 2     50 Cent
# 3     50 Cent
# 4     50 Cent

# %%
df_final.shape
# Out:
# (42940, 3)

# %%
type(df_final)
# Out:
# pandas.core.frame.DataFrame

# %%
# Delete Empty rows
for i in range(len(df_final['lyrics_row'])):
    if len(df_final['lyrics_row'][i])==0:
        df_final.drop(i, axis=0, inplace=True)

# %%
df_final.shape
# Out:
# (22981, 3)

# %%
df_final = df_final.reset_index()
df_final = df_final.drop('index', axis=1)
df_final.head()
# Out:
#                                           lyrics_row          song_name  \
# 0  Yeah, I was born a misfit, grew up ten miles f...  Remember the Name
# 1    Wanted to make it big, I wished it to existence  Remember the Name
# 2     I never was a sick kid, always dismissed quick  Remember the Name
# 3  "Stick to singing, stop rappin'", like it's Ch...  Remember the Name
# 4  And if you're talkin' money, then my conversat...  Remember the Name
#
#   artist_name
# 0     50 Cent
# 1     50 Cent
# 2     50 Cent
# 3     50 Cent
# 4     50 Cent
